# %%
import pandas as pd

# %%
df_anime = pd.read_csv(r"D:\Ashish Doc\Ashish\AI-engineer\4. Machine-Learning-DS\ML CampusX\3. Data Understanding\anime.csv")

# %%
df_anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %% [markdown]
# ## Categorical Data (Qualitative)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")

sns.countplot(df_anime['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
df_anime['type'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### Histogram

# %%
df_anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df_anime['rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.kdeplot(df_anime['rating'], fill=True,)
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %%
sns.histplot(df_anime['rating'], bins=30, kde=True)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
sns.boxplot(df_anime['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
df_anime['rating'].describe()
# Out:
# count    12064.000000
# mean         6.473902
# std          1.026746
# min          1.670000
# 25%          5.880000
# 50%          6.570000
# 75%          7.180000
# max         10.000000
# Name: rating, dtype: float64

# %%
df_anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df_anime['episodes'].describe()
# Out:
# count     12294
# unique      187
# top           1
# freq       5677
# Name: episodes, dtype: object

# %%
df_anime['members'].describe()
# Out:
# count    1.229400e+04
# mean     1.807134e+04
# std      5.482068e+04
# min      5.000000e+00
# 25%      2.250000e+02
# 50%      1.550000e+03
# 75%      9.437000e+03
# max      1.013917e+06
# Name: members, dtype: float64

# %%
import pandas as pd

# %%
df_anime = pd.read_csv("anime.csv")

# %%
df_anime.shape
# Out:
# (12294, 7)

# %%
df_anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df_anime.tail()
# Out:
#        anime_id                                               name   genre  \
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami  Hentai
# 12290      5543                                        Under World  Hentai
# 12291      5621                     Violence Gekiga David no Hoshi  Hentai
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...  Hentai
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!  Hentai
#
#         type episodes  rating  members
# 12289    OVA        1    4.15      211
# 12290    OVA        1    4.28      183
# 12291    OVA        4    4.88      219
# 12292    OVA        1    4.98      175
# 12293  Movie        1    5.46      142

# %%
df_anime.sample(3)
# Out:
#       anime_id                                name                  genre  \
# 181       9890                      Major: Message  Comedy, Drama, Sports
# 9709     27843  Nemurenu Yoru no Chiisana Ohanashi                   Kids
# 6523     23903                Tuzki: Love Assassin        Comedy, Romance
#
#      type episodes  rating  members
# 181   OVA        1    8.36    12282
# 9709  OVA        3    6.25       53
# 6523  ONA        1    6.08      309

# %%
df_anime.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  str
#  2   genre     12232 non-null  str
#  3   type      12269 non-null  str
#  4   episodes  12294 non-null  str
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 1.3 MB

# %%
df_anime.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df_anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
df_anime.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_anime.corr(numeric_only=True)['rating']
# Out:
# anime_id   -0.284625
# rating      1.000000
# members     0.387979
# Name: rating, dtype: float64

# %%
df_rating = pd.read_csv("rating.csv")

# %%
df_rating.shape
# Out:
# (7813737, 3)

# %%
df_rating.sample(3)
# Out:
#          user_id  anime_id  rating
# 2287613    22026      5081       9
# 1245744    11755      8675       7
# 6199810    57951       584      10

# %%
df_rating.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB

# %%
df_rating.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
df_rating.describe()
# Out:
#             user_id      anime_id        rating
# count  7.813737e+06  7.813737e+06  7.813737e+06
# mean   3.672796e+04  8.909072e+03  6.144030e+00
# std    2.099795e+04  8.883950e+03  3.727800e+00
# min    1.000000e+00  1.000000e+00 -1.000000e+00
# 25%    1.897400e+04  1.240000e+03  6.000000e+00
# 50%    3.679100e+04  6.213000e+03  7.000000e+00
# 75%    5.475700e+04  1.409300e+04  9.000000e+00
# max    7.351600e+04  3.451900e+04  1.000000e+01

# %%
df_rating.duplicated().sum()
# Out:
# np.int64(1)

# %%
df_rating.corr()
# Out:
#            user_id  anime_id    rating
# user_id   1.000000 -0.031642  0.002467
# anime_id -0.031642  1.000000 -0.005888
# rating    0.002467 -0.005888  1.000000
